# %%
import os
import json
import pickle
import sys
sys.path.insert(0, '../')
from trainRNNbrain.datasaver.DataSaver import DataSaver
from trainRNNbrain.analyzers.DynamicSystemAnalyzer import *
from trainRNNbrain.analyzers.PerformanceAnalyzer import *
from trainRNNbrain.rnns.RNN_numpy import RNN_numpy
from trainRNNbrain.rnns.RNN_torch import RNN_torch
from trainRNNbrain.utils import get_project_root, numpify, orthonormalize
from trainRNNbrain.trainer.Trainer import Trainer
from trainRNNbrain.tasks.TaskCDDM import *
from matplotlib import pyplot as plt
import torch
import time
from sklearn.decomposition import PCA

# %%
import typing as T
import os
import matplotlib.colors as mcolors
import matplotlib.font_manager as mfonts
from trainRNNbrain.utils import get_project_root
from matplotlib import pyplot as plt

def setup_fonts(fontpaths, verbose: bool = False, **kwargs):
    for font in sorted(mfonts.findSystemFonts(fontpaths=fontpaths, **kwargs)):
        mfonts.fontManager.addfont(font)
        if verbose: print(f'font:\t{os.path.basename(font)}')


def setup_colors(themepaths, verbose: bool = False):
    for themepath in themepaths:
        with open(themepath, 'rt') as f:
            lines = f.readlines()
            for line in lines:
                line = line.strip()
                if line.startswith('#'): continue
                names, value = line.split(':')
                value = value.strip()
                for name in names.split(','):
                    name = name.strip()
                    mcolors._colors_full_map[name] = value  # type: ignore
                    if verbose: print(f'color:\t{name:16s} {value:}')

setup_fonts([os.path.join(get_project_root(), "style", "assets", "fonts")], verbose=False)
setup_colors([os.path.join(get_project_root(), "style", "assets", "styles", "scientific.txt")], verbose=False)
plt.style.use([os.path.join(get_project_root(), 'style', 'assets', 'styles', 'scientific.mplstyle'), {'figure.dpi': 144}])

# %%
# defining RNN:
N = 50
activation_name = 'relu'
activation_slope = 1.0
exc_to_inh_ratio = 4.0 # there 4 times more excitatory neurons
dt = 1
tau = 10
constrained = True # whether to impose Dale constraint and positivity of inputs and outputs
connectivity_density_rec = 1.0 # no sparsity here
spectral_rad = 1.2 
sigma_inp = 0.05
sigma_rec = 0.05
seed = 0
input_size = 6
output_size = 2

# %%
# Task:
T = 60
n_steps = int(np.ceil(T/dt))
cue_on = 0
cue_off = n_steps
stim_on = n_steps//3
stim_off = n_steps
dec_on = 2 * n_steps//3
dec_off = n_steps
abs_coherences = np.array([0.02, 0.05, 0.1, 0.2, 0.5, 1])
coherences = np.concatenate([-1.0 * abs_coherences[::-1], np.array([0]), abs_coherences])

# %%
# Trainer:
lambda_orth = 0.3
lambda_r = 0.5
train_mask = np.concatenate([np.arange(n_steps//3), 2 * (n_steps//3) + np.arange(n_steps//3)])
max_iter = 500
tol = 1e-10
lr = 0.02
weight_decay = 1e-6
same_batch = True # generate new bath every new iteration

# %%
# creating instances:
#RNN
rnn_torch = RNN_torch(N=N,
                      activation_name=activation_name,
                      activation_slope=activation_slope,
                      exc_to_inh_ratio=exc_to_inh_ratio,
                      dt=dt,
                      tau=tau,
                      input_size=input_size,
                      output_size=output_size,
                      constrained=constrained,
                      sigma_inp=sigma_inp,
                      sigma_rec=sigma_rec,
                      connectivity_density_rec=connectivity_density_rec,
                      spectral_rad=spectral_rad,
                      seed=seed)

#task
task = TaskCDDM(n_steps=n_steps,
                n_inputs=input_size,
                n_outputs=output_size, 
                cue_on=cue_on, cue_off=cue_off,
                stim_on=stim_on, stim_off=stim_off,
                dec_on=dec_on, dec_off=dec_off,
               coherences=coherences)

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(rnn_torch.parameters(),
                             lr=lr,
                             weight_decay=weight_decay)
#trainer
trainer = Trainer(RNN=rnn_torch, Task=task,
                  max_iter=max_iter, tol=tol,
                  optimizer=optimizer, criterion=criterion,
                  lambda_orth=lambda_orth, lambda_r=lambda_r)
datasaver = None
# Out:
# Using cpu for RNN!

# %%
#plotting individual trials
ind = 11

inputs, targets, conditions = task.get_batch()
fig = plt.figure(figsize = (5, 2))
plt.plot(inputs[0, :, ind] + 0.01 * np.random.randn(), color = 'red', linewidth=2, label = 'context motion')
plt.plot(inputs[1, :, ind] + 0.01 * np.random.randn(), color = 'blue', linewidth=2,label = 'context color')
plt.plot(inputs[2, :, ind], color = 'tomato', linewidth=2, label = 'motion right')
plt.plot(inputs[3, :, ind], color = 'orange', linewidth=2, alpha = 0.8, label = 'motion left')
plt.plot(inputs[4, :, ind], color = 'deepskyblue', linewidth=2, label = 'color right')
plt.plot(inputs[5, :, ind], color = 'magenta', linewidth=2, alpha = 0.8, label = 'color left')
plt.plot(targets[0, :, ind] + 0.01 * np.random.randn(), color = 'darkgreen', linewidth=2, linestyle = '--', label = 'target')
plt.plot(targets[1, :, ind] + 0.01 * np.random.randn(), color = 'green', linewidth=2, linestyle = '--', label = 'target')
plt.legend(loc = 0)
plt.ylim([-0.05, 1.05])
plt.show()

# %%
# # training RNNs
# trained_rnn, train_losses, val_losses, best_rnn_params = trainer.run_training(train_mask=train_mask, same_batch=same_batch, shuffle=False)

# #save the parameters
# # pickle.dump(best_rnn_params, open("./training_CDDM_example/best_rnn_params_CDDM.pkl", "wb+"))

# fig_trainloss = plt.figure(figsize=(5, 2))
# plt.plot(train_losses, linewidth=2, color='r', label='train loss (log scale)')
# plt.plot(val_losses, linewidth=2, color='b', label='valid loss (log scale)')
# plt.yscale("log")
# plt.grid(True)
# plt.xlabel("# epoch")
# plt.ylabel("Loss")
# plt.legend()
# plt.show()
# Out:
# iteration 0, train loss: 1.928688, validation loss: 1.839331
# iteration 1, train loss: 1.835427, validation loss: 1.823878
# iteration 2, train loss: 1.826859, validation loss: 1.792336
# iteration 3, train loss: 1.79475, validation loss: 1.740066
# iteration 4, train loss: 1.742762, validation loss: 1.66331
# iteration 5, train loss: 1.664797, validation loss: 1.563133
# iteration 6, train loss: 1.564456, validation loss: 1.45336
# iteration 7, train loss: 1.455582, validation loss: 1.353162
# iteration 8, train loss: 1.354435, validation loss: 1.264596
# iteration 9, train loss: 1.266575, validation loss: 1.181315
# iteration 10, train loss: 1.18365, validation loss: 1.105798
# iteration 11, train loss: 1.107623, validation loss: 1.032785
# iteration 12, train loss: 1.033992, validation loss: 0.962212
# iteration 13, train loss: 0.96348, validation loss: 0.894864
# iteration 14, train loss: 0.896049, validation loss: 0.831274
# iteration 15, train loss: 0.831906, validation loss: 0.771664
# iteration 16, train loss: 0.772721, validation loss: 0.717134
# iteration 17, train loss: 0.717695, validation loss: 0.66903
# iteration 18, train loss: 0.66887, validation loss: 0.627414
# iteration 19, train loss: 0.62704, validation loss: 0.593292
# iteration 20, train loss: 0.592796, validation loss: 0.563383
# iteration 21, train loss: 0.563004, validation loss: 0.536947
# iteration 22, train loss: 0.536494, validation loss: 0.511837
# iteration 23, train loss: 0.511381, validation loss: 0.489468
# iteration 24, train loss: 0.489183, validation loss: 0.469743
# iteration 25, train loss: 0.469315, validation loss: 0.451109
# iteration 26, train loss: 0.45114, validation loss: 0.433181
# iteration 27, train loss: 0.433268, validation loss: 0.41551
# iteration 28, train loss: 0.415643, validation loss: 0.397786
# iteration 29, train loss: 0.398757, validation loss: 0.380843
# iteration 30, train loss: 0.381965, validation loss: 0.363798
# iteration 31, train loss: 0.365029, validation loss: 0.347057
# iteration 32, train loss: 0.348751, validation loss: 0.330655
# iteration 33, train loss: 0.332457, validation loss: 0.31498
# iteration 34, train loss: 0.316222, validation loss: 0.300099
# iteration 35, train loss: 0.302581, validation loss: 0.286177
# iteration 36, train loss: 0.289269, validation loss: 0.273093
# iteration 37, train loss: 0.276297, validation loss: 0.260979
# iteration 38, train loss: 0.265095, validation loss: 0.250075
# iteration 39, train loss: 0.254043, validation loss: 0.240002
# iteration 40, train loss: 0.243934, validation loss: 0.230796
# iteration 41, train loss: 0.235386, validation loss: 0.222637
# iteration 42, train loss: 0.228987, validation loss: 0.215246
# iteration 43, train loss: 0.220957, validation loss: 0.20833
# iteration 44, train loss: 0.213781, validation loss: 0.201763
# iteration 45, train loss: 0.208724, validation loss: 0.19521
# iteration 46, train loss: 0.200814, validation loss: 0.188232
# iteration 47, train loss: 0.194258, validation loss: 0.180886
# iteration 48, train loss: 0.187815, validation loss: 0.173582
# iteration 49, train loss: 0.18108, validation loss: 0.166691
# iteration 50, train loss: 0.173051, validation loss: 0.160642
# iteration 51, train loss: 0.168031, validation loss: 0.155383
# iteration 52, train loss: 0.163782, validation loss: 0.150435
# iteration 53, train loss: 0.156104, validation loss: 0.145852
# iteration 54, train loss: 0.152744, validation loss: 0.141618
# iteration 55, train loss: 0.149277, validation loss: 0.137798
# iteration 56, train loss: 0.144699, validation loss: 0.134698
# iteration 57, train loss: 0.141393, validation loss: 0.132251
# iteration 58, train loss: 0.139296, validation loss: 0.129959
# iteration 59, train loss: 0.137415, validation loss: 0.127525
# iteration 60, train loss: 0.135724, validation loss: 0.124749
# iteration 61, train loss: 0.134315, validation loss: 0.121943
# iteration 62, train loss: 0.128825, validation loss: 0.119232
# iteration 63, train loss: 0.127782, validation loss: 0.116627
# iteration 64, train loss: 0.12665, validation loss: 0.113991
# iteration 65, train loss: 0.125121, validation loss: 0.111316
# iteration 66, train loss: 0.119934, validation loss: 0.108537
# iteration 67, train loss: 0.118459, validation loss: 0.105814
# iteration 68, train loss: 0.118892, validation loss: 0.103356
# iteration 69, train loss: 0.115407, validation loss: 0.101188
# iteration 70, train loss: 0.113758, validation loss: 0.099424
# iteration 71, train loss: 0.111094, validation loss: 0.098074
# iteration 72, train loss: 0.112861, validation loss: 0.096981
# iteration 73, train loss: 0.111443, validation loss: 0.096101
# iteration 74, train loss: 0.111014, validation loss: 0.095289
# iteration 75, train loss: 0.1091, validation loss: 0.094398
# iteration 76, train loss: 0.107179, validation loss: 0.093405
# iteration 77, train loss: 0.105422, validation loss: 0.09233
# iteration 78, train loss: 0.106485, validation loss: 0.091206
# iteration 79, train loss: 0.106717, validation loss: 0.090009
# iteration 80, train loss: 0.101657, validation loss: 0.088883
# iteration 81, train loss: 0.101961, validation loss: 0.087809
# iteration 82, train loss: 0.098992, validation loss: 0.086678
# iteration 83, train loss: 0.10167, validation loss: 0.085511
# iteration 84, train loss: 0.100151, validation loss: 0.084374
# iteration 85, train loss: 0.101126, validation loss: 0.083388
# iteration 86, train loss: 0.099313, validation loss: 0.082493
# iteration 87, train loss: 0.097282, validation loss: 0.081745
# iteration 88, train loss: 0.098291, validation loss: 0.081025
# iteration 89, train loss: 0.094713, validation loss: 0.080178
# iteration 90, train loss: 0.09582, validation loss: 0.079262
# iteration 91, train loss: 0.091331, validation loss: 0.078335
# iteration 92, train loss: 0.090885, validation loss: 0.077574
# iteration 93, train loss: 0.090809, validation loss: 0.076992
# iteration 94, train loss: 0.091365, validation loss: 0.076634
# iteration 95, train loss: 0.092446, validation loss: 0.076232
# iteration 96, train loss: 0.089143, validation loss: 0.075684
# iteration 97, train loss: 0.090729, validation loss: 0.075081
# iteration 98, train loss: 0.087545, validation loss: 0.074504
# iteration 99, train loss: 0.087884, validation loss: 0.074023
# iteration 100, train loss: 0.0868, validation loss: 0.073616
# iteration 101, train loss: 0.087312, validation loss: 0.0732
# iteration 102, train loss: 0.089362, validation loss: 0.072782
# iteration 103, train loss: 0.08643, validation loss: 0.072392
# iteration 104, train loss: 0.088185, validation loss: 0.072111
# iteration 105, train loss: 0.083187, validation loss: 0.071826
# iteration 106, train loss: 0.084385, validation loss: 0.071553
# iteration 107, train loss: 0.085055, validation loss: 0.071308
# iteration 108, train loss: 0.083757, validation loss: 0.071177
# iteration 109, train loss: 0.084591, validation loss: 0.070912
# iteration 110, train loss: 0.084885, validation loss: 0.070219
# iteration 111, train loss: 0.08574, validation loss: 0.069543
# iteration 112, train loss: 0.083951, validation loss: 0.069044
# iteration 113, train loss: 0.083868, validation loss: 0.068642
# iteration 114, train loss: 0.083678, validation loss: 0.068192
# iteration 115, train loss: 0.083279, validation loss: 0.06784
# iteration 116, train loss: 0.083516, validation loss: 0.067604
# iteration 117, train loss: 0.080542, validation loss: 0.067423
# iteration 118, train loss: 0.082097, validation loss: 0.067391
# iteration 119, train loss: 0.081633, validation loss: 0.067364
# iteration 120, train loss: 0.079956, validation loss: 0.067116
# iteration 121, train loss: 0.079469, validation loss: 0.066683
# iteration 122, train loss: 0.079413, validation loss: 0.066369
# iteration 123, train loss: 0.079361, validation loss: 0.065677
# iteration 124, train loss: 0.078552, validation loss: 0.064897
# iteration 125, train loss: 0.081631, validation loss: 0.064249
# iteration 126, train loss: 0.078873, validation loss: 0.063905
# iteration 127, train loss: 0.081615, validation loss: 0.063781
# iteration 128, train loss: 0.078911, validation loss: 0.063807
# iteration 129, train loss: 0.082513, validation loss: 0.063671
# iteration 130, train loss: 0.07886, validation loss: 0.063169
# iteration 131, train loss: 0.081415, validation loss: 0.06285
# iteration 132, train loss: 0.079205, validation loss: 0.062591
# iteration 133, train loss: 0.082095, validation loss: 0.062283
# iteration 134, train loss: 0.081337, validation loss: 0.062004
# iteration 135, train loss: 0.078315, validation loss: 0.062154
# iteration 136, train loss: 0.079817, validation loss: 0.062214
# iteration 137, train loss: 0.077521, validation loss: 0.061724
# iteration 138, train loss: 0.081401, validation loss: 0.061099
# iteration 139, train loss: 0.078619, validation loss: 0.060849
# iteration 140, train loss: 0.081982, validation loss: 0.060814
# iteration 141, train loss: 0.074973, validation loss: 0.060508
# iteration 142, train loss: 0.076009, validation loss: 0.060306
# iteration 143, train loss: 0.079542, validation loss: 0.060551
# iteration 144, train loss: 0.075462, validation loss: 0.060617
# iteration 145, train loss: 0.076795, validation loss: 0.06014
# iteration 146, train loss: 0.075221, validation loss: 0.059503
# iteration 147, train loss: 0.079019, validation loss: 0.059039
# iteration 148, train loss: 0.076133, validation loss: 0.059004
# iteration 149, train loss: 0.078392, validation loss: 0.059502
# iteration 150, train loss: 0.077579, validation loss: 0.059088
# iteration 151, train loss: 0.077665, validation loss: 0.058159
# iteration 152, train loss: 0.077, validation loss: 0.058029
# iteration 153, train loss: 0.075187, validation loss: 0.058281
# iteration 154, train loss: 0.074961, validation loss: 0.057935
# iteration 155, train loss: 0.079773, validation loss: 0.057681
# iteration 156, train loss: 0.078964, validation loss: 0.057806
# iteration 157, train loss: 0.077035, validation loss: 0.057704
# iteration 158, train loss: 0.078225, validation loss: 0.057245
# iteration 159, train loss: 0.074742, validation loss: 0.056942
# iteration 160, train loss: 0.074799, validation loss: 0.056689
# iteration 161, train loss: 0.075813, validation loss: 0.056432
# iteration 162, train loss: 0.08086, validation loss: 0.056406
# iteration 163, train loss: 0.076612, validation loss: 0.056818
# iteration 164, train loss: 0.07626, validation loss: 0.056936
# iteration 165, train loss: 0.078733, validation loss: 0.05645
# iteration 166, train loss: 0.076229, validation loss: 0.055949
# iteration 167, train loss: 0.079695, validation loss: 0.055847
# iteration 168, train loss: 0.077594, validation loss: 0.055924
# iteration 169, train loss: 0.073033, validation loss: 0.055932
# iteration 170, train loss: 0.075845, validation loss: 0.056066
# iteration 171, train loss: 0.073454, validation loss: 0.055891
# iteration 172, train loss: 0.075166, validation loss: 0.05547
# iteration 173, train loss: 0.073442, validation loss: 0.054966
# iteration 174, train loss: 0.079432, validation loss: 0.054712
# iteration 175, train loss: 0.076624, validation loss: 0.054637
# iteration 176, train loss: 0.075714, validation loss: 0.05516
# iteration 177, train loss: 0.07556, validation loss: 0.055552
# iteration 178, train loss: 0.072963, validation loss: 0.055635
# iteration 179, train loss: 0.075776, validation loss: 0.055052
# iteration 180, train loss: 0.077648, validation loss: 0.054917
# iteration 181, train loss: 0.075842, validation loss: 0.055096
# iteration 182, train loss: 0.078838, validation loss: 0.055142
# iteration 183, train loss: 0.075587, validation loss: 0.055146
# iteration 184, train loss: 0.069923, validation loss: 0.055196
# iteration 185, train loss: 0.079549, validation loss: 0.054111
# iteration 186, train loss: 0.075386, validation loss: 0.053563
# iteration 187, train loss: 0.07408, validation loss: 0.053463
# iteration 188, train loss: 0.075172, validation loss: 0.053382
# iteration 189, train loss: 0.076152, validation loss: 0.053562
# iteration 190, train loss: 0.074324, validation loss: 0.054074
# iteration 191, train loss: 0.076009, validation loss: 0.053817
# iteration 192, train loss: 0.073391, validation loss: 0.05338
# iteration 193, train loss: 0.07368, validation loss: 0.053259
# iteration 194, train loss: 0.070625, validation loss: 0.052995
# iteration 195, train loss: 0.074342, validation loss: 0.052629
# iteration 196, train loss: 0.073601, validation loss: 0.052507
# iteration 197, train loss: 0.07666, validation loss: 0.052592
# iteration 198, train loss: 0.075228, validation loss: 0.053288
# iteration 199, train loss: 0.071606, validation loss: 0.054244
# iteration 200, train loss: 0.073433, validation loss: 0.053815
# iteration 201, train loss: 0.072589, validation loss: 0.052177
# iteration 202, train loss: 0.07706, validation loss: 0.051901
# iteration 203, train loss: 0.07631, validation loss: 0.051722
# iteration 204, train loss: 0.071882, validation loss: 0.052098
# iteration 205, train loss: 0.075323, validation loss: 0.05319
# iteration 206, train loss: 0.071808, validation loss: 0.053346
# iteration 207, train loss: 0.076709, validation loss: 0.052045
# iteration 208, train loss: 0.072702, validation loss: 0.051438
# iteration 209, train loss: 0.074442, validation loss: 0.051392
# iteration 210, train loss: 0.074865, validation loss: 0.051254
# iteration 211, train loss: 0.072855, validation loss: 0.051677
# iteration 212, train loss: 0.076847, validation loss: 0.051665
# iteration 213, train loss: 0.072403, validation loss: 0.051593
# iteration 214, train loss: 0.07585, validation loss: 0.051615
# iteration 215, train loss: 0.072049, validation loss: 0.051448
# iteration 216, train loss: 0.074792, validation loss: 0.051435
# iteration 217, train loss: 0.074243, validation loss: 0.052669
# iteration 218, train loss: 0.074026, validation loss: 0.052474
# iteration 219, train loss: 0.076052, validation loss: 0.0525
# iteration 220, train loss: 0.080018, validation loss: 0.051864
# iteration 221, train loss: 0.073169, validation loss: 0.05186
# iteration 222, train loss: 0.071171, validation loss: 0.052252
# iteration 223, train loss: 0.076474, validation loss: 0.051695
# iteration 224, train loss: 0.074408, validation loss: 0.051292
# iteration 225, train loss: 0.071944, validation loss: 0.051185
# iteration 226, train loss: 0.072481, validation loss: 0.051233
# iteration 227, train loss: 0.074206, validation loss: 0.051079
# iteration 228, train loss: 0.073514, validation loss: 0.050899
# iteration 229, train loss: 0.072642, validation loss: 0.050919
# iteration 230, train loss: 0.074073, validation loss: 0.050865
# iteration 231, train loss: 0.072841, validation loss: 0.051191
# iteration 232, train loss: 0.075004, validation loss: 0.052199
# iteration 233, train loss: 0.072299, validation loss: 0.052587
# iteration 234, train loss: 0.07433, validation loss: 0.051427
# iteration 235, train loss: 0.071452, validation loss: 0.051257
# iteration 236, train loss: 0.074826, validation loss: 0.051374
# iteration 237, train loss: 0.075261, validation loss: 0.051151
# iteration 238, train loss: 0.070761, validation loss: 0.051417
# iteration 239, train loss: 0.074509, validation loss: 0.051631
# iteration 240, train loss: 0.077747, validation loss: 0.052085
# iteration 241, train loss: 0.071235, validation loss: 0.051465
# iteration 242, train loss: 0.073824, validation loss: 0.050958
# iteration 243, train loss: 0.075119, validation loss: 0.050796
# iteration 244, train loss: 0.073573, validation loss: 0.050839
# iteration 245, train loss: 0.074411, validation loss: 0.051416
# iteration 246, train loss: 0.074527, validation loss: 0.051108
# iteration 247, train loss: 0.073765, validation loss: 0.050704
# iteration 248, train loss: 0.072552, validation loss: 0.05088
# iteration 249, train loss: 0.07261, validation loss: 0.050891
# iteration 250, train loss: 0.072093, validation loss: 0.050449
# iteration 251, train loss: 0.069029, validation loss: 0.052366
# iteration 252, train loss: 0.072857, validation loss: 0.054105
# iteration 253, train loss: 0.069902, validation loss: 0.052218
# iteration 254, train loss: 0.076778, validation loss: 0.050131
# iteration 255, train loss: 0.073067, validation loss: 0.050605
# iteration 256, train loss: 0.070287, validation loss: 0.050501
# iteration 257, train loss: 0.072976, validation loss: 0.049737
# iteration 258, train loss: 0.071037, validation loss: 0.052434
# iteration 259, train loss: 0.069714, validation loss: 0.053404
# iteration 260, train loss: 0.075465, validation loss: 0.050636
# iteration 261, train loss: 0.077998, validation loss: 0.049263
# iteration 262, train loss: 0.071977, validation loss: 0.050456
# iteration 263, train loss: 0.07081, validation loss: 0.049904
# iteration 264, train loss: 0.080149, validation loss: 0.050136
# iteration 265, train loss: 0.071023, validation loss: 0.053309
# iteration 266, train loss: 0.074802, validation loss: 0.055801
# iteration 267, train loss: 0.075754, validation loss: 0.052079
# iteration 268, train loss: 0.075919, validation loss: 0.049601
# iteration 269, train loss: 0.072946, validation loss: 0.051641
# iteration 270, train loss: 0.074851, validation loss: 0.050283
# iteration 271, train loss: 0.073084, validation loss: 0.049912
# iteration 272, train loss: 0.074762, validation loss: 0.051742
# iteration 273, train loss: 0.073081, validation loss: 0.051964
# iteration 274, train loss: 0.075012, validation loss: 0.05049
# iteration 275, train loss: 0.075634, validation loss: 0.049533
# iteration 276, train loss: 0.07368, validation loss: 0.049927
# iteration 277, train loss: 0.072917, validation loss: 0.050044
# iteration 278, train loss: 0.073698, validation loss: 0.050208
# iteration 279, train loss: 0.075983, validation loss: 0.051346
# iteration 280, train loss: 0.068796, validation loss: 0.05153
# iteration 281, train loss: 0.071504, validation loss: 0.050602
# iteration 282, train loss: 0.069971, validation loss: 0.049869
# iteration 283, train loss: 0.074926, validation loss: 0.050044
# iteration 284, train loss: 0.072629, validation loss: 0.049771
# iteration 285, train loss: 0.072061, validation loss: 0.049899
# iteration 286, train loss: 0.075597, validation loss: 0.050028
# iteration 287, train loss: 0.074406, validation loss: 0.050419
# iteration 288, train loss: 0.074259, validation loss: 0.050896
# iteration 289, train loss: 0.070159, validation loss: 0.049816
# iteration 290, train loss: 0.073178, validation loss: 0.049542
# iteration 291, train loss: 0.069957, validation loss: 0.050012
# iteration 292, train loss: 0.071736, validation loss: 0.049619
# iteration 293, train loss: 0.073338, validation loss: 0.050288
# iteration 294, train loss: 0.076542, validation loss: 0.05108
# iteration 295, train loss: 0.071806, validation loss: 0.050371
# iteration 296, train loss: 0.073796, validation loss: 0.049762
# iteration 297, train loss: 0.075207, validation loss: 0.049488
# iteration 298, train loss: 0.074687, validation loss: 0.049597
# iteration 299, train loss: 0.070607, validation loss: 0.049069
# iteration 300, train loss: 0.076226, validation loss: 0.049705
# iteration 301, train loss: 0.07548, validation loss: 0.051078
# iteration 302, train loss: 0.073794, validation loss: 0.050232
# iteration 303, train loss: 0.070492, validation loss: 0.050159
# iteration 304, train loss: 0.072059, validation loss: 0.049947
# iteration 305, train loss: 0.070527, validation loss: 0.04977
# iteration 306, train loss: 0.069085, validation loss: 0.051041
# iteration 307, train loss: 0.068628, validation loss: 0.05084
# iteration 308, train loss: 0.073808, validation loss: 0.05002
# iteration 309, train loss: 0.07311, validation loss: 0.049156
# iteration 310, train loss: 0.070362, validation loss: 0.04925
# iteration 311, train loss: 0.073663, validation loss: 0.048769
# iteration 312, train loss: 0.073523, validation loss: 0.04812
# iteration 313, train loss: 0.069788, validation loss: 0.047939
# iteration 314, train loss: 0.073509, validation loss: 0.048297
# iteration 315, train loss: 0.073311, validation loss: 0.049
# iteration 316, train loss: 0.071094, validation loss: 0.049237
# iteration 317, train loss: 0.073178, validation loss: 0.049533
# iteration 318, train loss: 0.073852, validation loss: 0.048652
# iteration 319, train loss: 0.072887, validation loss: 0.04832
# iteration 320, train loss: 0.071112, validation loss: 0.048338
# iteration 321, train loss: 0.068926, validation loss: 0.048584
# iteration 322, train loss: 0.069864, validation loss: 0.048594
# iteration 323, train loss: 0.074844, validation loss: 0.048467
# iteration 324, train loss: 0.069984, validation loss: 0.048603
# iteration 325, train loss: 0.07755, validation loss: 0.048557
# iteration 326, train loss: 0.07408, validation loss: 0.048449
# iteration 327, train loss: 0.074646, validation loss: 0.048459
# iteration 328, train loss: 0.068, validation loss: 0.048809
# iteration 329, train loss: 0.071702, validation loss: 0.048563
# iteration 330, train loss: 0.072738, validation loss: 0.048464
# iteration 331, train loss: 0.076194, validation loss: 0.049639
# iteration 332, train loss: 0.074539, validation loss: 0.050165
# iteration 333, train loss: 0.073603, validation loss: 0.049569
# iteration 334, train loss: 0.072381, validation loss: 0.048919
# iteration 335, train loss: 0.071456, validation loss: 0.049057
# iteration 336, train loss: 0.071677, validation loss: 0.048941
# iteration 337, train loss: 0.072491, validation loss: 0.048894
# iteration 338, train loss: 0.070924, validation loss: 0.049198
# iteration 339, train loss: 0.076822, validation loss: 0.049034
# iteration 340, train loss: 0.074377, validation loss: 0.048893
# iteration 341, train loss: 0.074478, validation loss: 0.048474
# iteration 342, train loss: 0.067592, validation loss: 0.049317
# iteration 343, train loss: 0.070369, validation loss: 0.049351
# iteration 344, train loss: 0.070968, validation loss: 0.048551
# iteration 345, train loss: 0.07102, validation loss: 0.048647
# iteration 346, train loss: 0.070806, validation loss: 0.04941
# iteration 347, train loss: 0.071983, validation loss: 0.048863
# iteration 348, train loss: 0.071899, validation loss: 0.048464
# iteration 349, train loss: 0.072517, validation loss: 0.047952
# iteration 350, train loss: 0.074339, validation loss: 0.047664
# iteration 351, train loss: 0.074322, validation loss: 0.047625
# iteration 352, train loss: 0.076726, validation loss: 0.047851
# iteration 353, train loss: 0.075997, validation loss: 0.047644
# iteration 354, train loss: 0.070672, validation loss: 0.047674
# iteration 355, train loss: 0.064442, validation loss: 0.048294
# iteration 356, train loss: 0.073093, validation loss: 0.047996
# iteration 357, train loss: 0.069292, validation loss: 0.047664
# iteration 358, train loss: 0.073616, validation loss: 0.047526
# iteration 359, train loss: 0.070762, validation loss: 0.047333
# iteration 360, train loss: 0.070727, validation loss: 0.047347
# iteration 361, train loss: 0.069774, validation loss: 0.047481
# iteration 362, train loss: 0.073846, validation loss: 0.047528
# iteration 363, train loss: 0.074057, validation loss: 0.048042
# iteration 364, train loss: 0.073348, validation loss: 0.047316
# iteration 365, train loss: 0.071887, validation loss: 0.047013
# iteration 366, train loss: 0.067407, validation loss: 0.04675
# iteration 367, train loss: 0.069281, validation loss: 0.046812
# iteration 368, train loss: 0.071492, validation loss: 0.047481
# iteration 369, train loss: 0.067258, validation loss: 0.048004
# iteration 370, train loss: 0.07297, validation loss: 0.046964
# iteration 371, train loss: 0.074759, validation loss: 0.046564
# iteration 372, train loss: 0.072031, validation loss: 0.047411
# iteration 373, train loss: 0.07668, validation loss: 0.046971
# iteration 374, train loss: 0.071716, validation loss: 0.047243
# iteration 375, train loss: 0.071212, validation loss: 0.048328
# iteration 376, train loss: 0.072241, validation loss: 0.048546
# iteration 377, train loss: 0.072637, validation loss: 0.047069
# iteration 378, train loss: 0.07528, validation loss: 0.046927
# iteration 379, train loss: 0.072473, validation loss: 0.047568
# iteration 380, train loss: 0.072041, validation loss: 0.046539
# iteration 381, train loss: 0.076159, validation loss: 0.046631
# iteration 382, train loss: 0.069742, validation loss: 0.048009
# iteration 383, train loss: 0.072219, validation loss: 0.048286
# iteration 384, train loss: 0.071808, validation loss: 0.046971
# iteration 385, train loss: 0.073388, validation loss: 0.046783
# iteration 386, train loss: 0.069095, validation loss: 0.047414
# iteration 387, train loss: 0.072896, validation loss: 0.047014
# iteration 388, train loss: 0.073594, validation loss: 0.046891
# iteration 389, train loss: 0.067329, validation loss: 0.0474
# iteration 390, train loss: 0.072413, validation loss: 0.047038
# iteration 391, train loss: 0.076157, validation loss: 0.047153
# iteration 392, train loss: 0.070447, validation loss: 0.04835
# iteration 393, train loss: 0.072452, validation loss: 0.048357
# iteration 394, train loss: 0.068542, validation loss: 0.047102
# iteration 395, train loss: 0.070316, validation loss: 0.047249
# iteration 396, train loss: 0.068332, validation loss: 0.049076
# iteration 397, train loss: 0.069621, validation loss: 0.04815
# iteration 398, train loss: 0.069878, validation loss: 0.046844
# iteration 399, train loss: 0.067653, validation loss: 0.049157
# iteration 400, train loss: 0.072621, validation loss: 0.047653
# iteration 401, train loss: 0.073453, validation loss: 0.046418
# iteration 402, train loss: 0.076151, validation loss: 0.048075
# iteration 403, train loss: 0.075867, validation loss: 0.048945
# iteration 404, train loss: 0.074325, validation loss: 0.047716
# iteration 405, train loss: 0.070161, validation loss: 0.047064
# iteration 406, train loss: 0.070589, validation loss: 0.048621
# iteration 407, train loss: 0.071729, validation loss: 0.048291
# iteration 408, train loss: 0.071921, validation loss: 0.046601
# iteration 409, train loss: 0.06452, validation loss: 0.046321
# iteration 410, train loss: 0.071687, validation loss: 0.046946
# iteration 411, train loss: 0.073962, validation loss: 0.046311
# iteration 412, train loss: 0.074315, validation loss: 0.046073
# iteration 413, train loss: 0.074119, validation loss: 0.046083
# iteration 414, train loss: 0.066231, validation loss: 0.045987
# iteration 415, train loss: 0.073348, validation loss: 0.045822
# iteration 416, train loss: 0.070201, validation loss: 0.045848
# iteration 417, train loss: 0.072135, validation loss: 0.046598
# iteration 418, train loss: 0.071211, validation loss: 0.046598
# iteration 419, train loss: 0.0743, validation loss: 0.046751
# iteration 420, train loss: 0.075348, validation loss: 0.047049
# iteration 421, train loss: 0.07186, validation loss: 0.046797
# iteration 422, train loss: 0.070434, validation loss: 0.046836
# iteration 423, train loss: 0.070867, validation loss: 0.04659
# iteration 424, train loss: 0.074706, validation loss: 0.046272
# iteration 425, train loss: 0.069631, validation loss: 0.047022
# iteration 426, train loss: 0.070988, validation loss: 0.04778
# iteration 427, train loss: 0.067928, validation loss: 0.047358
# iteration 428, train loss: 0.070256, validation loss: 0.046642
# iteration 429, train loss: 0.070107, validation loss: 0.047086
# iteration 430, train loss: 0.074471, validation loss: 0.047071
# iteration 431, train loss: 0.070701, validation loss: 0.046251
# iteration 432, train loss: 0.076123, validation loss: 0.046532
# iteration 433, train loss: 0.072127, validation loss: 0.04647
# iteration 434, train loss: 0.069283, validation loss: 0.046295
# iteration 435, train loss: 0.070354, validation loss: 0.046283
# iteration 436, train loss: 0.0742, validation loss: 0.046707
# iteration 437, train loss: 0.072086, validation loss: 0.046411
# iteration 438, train loss: 0.070083, validation loss: 0.046377
# iteration 439, train loss: 0.06918, validation loss: 0.046623
# iteration 440, train loss: 0.068111, validation loss: 0.046433
# iteration 441, train loss: 0.067352, validation loss: 0.045976
# iteration 442, train loss: 0.072529, validation loss: 0.04585
# iteration 443, train loss: 0.072456, validation loss: 0.045865
# iteration 444, train loss: 0.07162, validation loss: 0.046006
# iteration 445, train loss: 0.074102, validation loss: 0.046123
# iteration 446, train loss: 0.07306, validation loss: 0.045881
# iteration 447, train loss: 0.070711, validation loss: 0.045896
# iteration 448, train loss: 0.076219, validation loss: 0.045851
# iteration 449, train loss: 0.070217, validation loss: 0.045981
# iteration 450, train loss: 0.070652, validation loss: 0.046127
# iteration 451, train loss: 0.07046, validation loss: 0.046021
# iteration 452, train loss: 0.073143, validation loss: 0.045979
# iteration 453, train loss: 0.071333, validation loss: 0.046268
# iteration 454, train loss: 0.071102, validation loss: 0.046399
# iteration 455, train loss: 0.073238, validation loss: 0.046242
# iteration 456, train loss: 0.072109, validation loss: 0.046183
# iteration 457, train loss: 0.073432, validation loss: 0.046307
# iteration 458, train loss: 0.068941, validation loss: 0.046289
# iteration 459, train loss: 0.073205, validation loss: 0.046263
# iteration 460, train loss: 0.069893, validation loss: 0.046183
# iteration 461, train loss: 0.074708, validation loss: 0.046158
# iteration 462, train loss: 0.06902, validation loss: 0.046248
# iteration 463, train loss: 0.068202, validation loss: 0.046423
# iteration 464, train loss: 0.071607, validation loss: 0.046483
# iteration 465, train loss: 0.066844, validation loss: 0.046836
# iteration 466, train loss: 0.074514, validation loss: 0.046898
# iteration 467, train loss: 0.072161, validation loss: 0.046373
# iteration 468, train loss: 0.06741, validation loss: 0.04637
# iteration 469, train loss: 0.071817, validation loss: 0.046241
# iteration 470, train loss: 0.068119, validation loss: 0.045838
# iteration 471, train loss: 0.07379, validation loss: 0.04644
# iteration 472, train loss: 0.071702, validation loss: 0.047019
# iteration 473, train loss: 0.078634, validation loss: 0.046343
# iteration 474, train loss: 0.075417, validation loss: 0.045888
# iteration 475, train loss: 0.066013, validation loss: 0.046087
# iteration 476, train loss: 0.075269, validation loss: 0.046043
# iteration 477, train loss: 0.074716, validation loss: 0.045401
# iteration 478, train loss: 0.073742, validation loss: 0.045929
# iteration 479, train loss: 0.073328, validation loss: 0.046659
# iteration 480, train loss: 0.064972, validation loss: 0.04645
# iteration 481, train loss: 0.071009, validation loss: 0.045806
# iteration 482, train loss: 0.07107, validation loss: 0.045681
# iteration 483, train loss: 0.071325, validation loss: 0.045941
# iteration 484, train loss: 0.07308, validation loss: 0.046548
# iteration 485, train loss: 0.072629, validation loss: 0.047433
# iteration 486, train loss: 0.06837, validation loss: 0.047307
# iteration 487, train loss: 0.076212, validation loss: 0.047406
# iteration 488, train loss: 0.071388, validation loss: 0.047581
# iteration 489, train loss: 0.074582, validation loss: 0.047091
# iteration 490, train loss: 0.067425, validation loss: 0.046481
# iteration 491, train loss: 0.070929, validation loss: 0.046476
# iteration 492, train loss: 0.070904, validation loss: 0.046526
# iteration 493, train loss: 0.070227, validation loss: 0.046703
# iteration 494, train loss: 0.076986, validation loss: 0.046129
# iteration 495, train loss: 0.068557, validation loss: 0.045655
# iteration 496, train loss: 0.074043, validation loss: 0.045879
# iteration 497, train loss: 0.073491, validation loss: 0.045685
# iteration 498, train loss: 0.073868, validation loss: 0.045739
# iteration 499, train loss: 0.072328, validation loss: 0.046411

# %%
best_rnn_params = pickle.load(open("./training_CDDM_example/best_rnn_params_CDDM.pkl", "rb+"))
best_rnn_params.keys()
# Out:
# dict_keys(['activation_name', 'activation_slope', 'W_out', 'W_inp', 'W_rec', 'y_init', 'N', 'dt', 'tau'])

# %%
# validate
RNN_valid = RNN_numpy(N=best_rnn_params["N"],
                      dt=best_rnn_params["dt"],
                      tau=best_rnn_params["tau"],
                      W_inp=best_rnn_params["W_inp"],
                      W_rec=best_rnn_params["W_rec"],
                      W_out=best_rnn_params["W_out"],
                      activation_name=activation_name,
                      activation_slope=activation_slope)

# %%
analyzer = PerformanceAnalyzerCDDM(RNN_valid)
score_function = lambda x, y: np.mean((x - y) ** 2)
input_batch_valid, target_batch_valid, conditions_valid = task.get_batch()
score = analyzer.get_validation_score(score_function, input_batch_valid, target_batch_valid,
                                      train_mask, sigma_rec=sigma_rec, sigma_inp=sigma_inp)

# %%
print(f"MSE validation: {np.round(score, 5)}")
if not (datasaver is None): datasaver.save_data(config_dict, "config.json")
if not (datasaver is None): datasaver.save_data(best_net_params, f"params_{taskname}_{np.round(score, 5)}.pkl")
# Out:
# MSE validation: 0.07066

# %%
print(f"Plotting random trials")
inds = np.random.choice(np.arange(input_batch_valid.shape[-1]), 12)
inputs = input_batch_valid[..., inds]
targets = target_batch_valid[..., inds]
conditions = [conditions_valid[ind] for ind in inds]

analyzer.plot_trials(input_batch=inputs, target_batch=targets, mask=train_mask, sigma_rec=sigma_rec, sigma_inp=sigma_inp, conditions=conditions)
plt.show()
# Out:
# Plotting random trials

# %%
num_levels = len(coherences)
analyzer.calc_psychometric_data(task, train_mask, num_levels=num_levels, num_repeats=31, sigma_rec=0.03, sigma_inp=0.03)
fig_psycho = analyzer.plot_psychometric_data(show_axeslabels=True, show_MSE_surface=True, show_colorbar = True)
plt.show()

# %%
RNN_valid.reset_state()
RNN_valid.clear_history()

# %%
dsa = DynamicSystemAnalyzerCDDM(RNN_valid, task)

params = {"fun_tol" : 0.05,
          "diff_cutoff":1e-4,
          "sigma_init_guess":15,
          "patience":100,
          "stop_length":100,
          "mode":"approx"}

dsa.get_fixed_points(Input=np.array([1, 0, 0.5, 0.5, 0.5, 0.5]), **params)
dsa.get_fixed_points(Input=np.array([0, 1, 0.5, 0.5, 0.5, 0.5]), **params)

pickle.dump(dsa.fp_data, open("./training_CDDM_example/fp_data.pkl", "wb+"))

# %%
choice_axis = RNN_valid.W_out.flatten() if RNN_valid.W_out.shape[0] == 1 else (RNN_valid.W_out[0, :] - RNN_valid.W_out[1, :])
context_axis = RNN_valid.W_inp[:, 0] - RNN_valid.W_inp[:, 1]
sensory_axis = np.sum([RNN_valid.W_inp[:, i] for i in [2, 3, 4, 5]])

P_matrix = np.zeros((RNN_valid.N, 3))
P_matrix[:, 0] = choice_axis
P_matrix[:, 1] = context_axis
P_matrix[:, 2] = sensory_axis

# %%
# %matplotlib widget
fp_data = pickle.load(open("./training_CDDM_example/fp_data.pkl", "rb+"))
dsa = DynamicSystemAnalyzerCDDM(RNN_valid, task)
dsa.fp_data = fp_data
fig_fp = dsa.plot_fixed_points(projection='3D', P=P_matrix)
plt.xlabel("Output axis", fontsize=16)
plt.show()

# %%
dsa.calc_LineAttractor_analytics()
# Out:
# Analyzing points on a line attractor in motion context...
#   0%|          | 0/31 [00:00<?, ?it/s]
# Analyzing points on a line attractor in color context...
#   0%|          | 0/31 [00:00<?, ?it/s]

# %%
# %matplotlib widget
fig_LA = dsa.plot_LineAttractor_3D()
plt.show()
