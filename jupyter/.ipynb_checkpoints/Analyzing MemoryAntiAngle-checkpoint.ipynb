# %%
import os
import json
import pickle
import sys
sys.path.insert(0, '../')
from src.DataSaver import DataSaver
from src.DynamicSystemAnalyzer import DynamicSystemAnalyzer
from src.PerformanceAnalyzer import PerformanceAnalyzer
from src.RNN_numpy import RNN_numpy
from src.utils import get_project_root, numpify, orthonormalize
from src.Trainer import Trainer
from src.RNN_torch import RNN_torch
from src.Task import *
from matplotlib import pyplot as plt
import torch
import time
from sklearn.decomposition import PCA

# %%
disp = True
activation = "tanh"
taskname = "MemoryAntiAngle"
train_config_file = f"train_config_{taskname}_{activation}.json"
config_dict = json.load(open(os.path.join(get_project_root(), "data", "configs", train_config_file), mode="r"))

# %%
# defining RNN:
N = config_dict["N"]
activation_name = config_dict["activation"]
if activation_name == 'relu':
    activation = lambda x: torch.maximum(x, torch.tensor(0))
elif activation_name == 'tanh':
    activation = torch.tanh
elif activation_name == 'sigmoid':
    activation = lambda x: 1/(1 + torch.exp(-x))
elif activation_name == 'softplus':
    activation = lambda x: torch.log(1 + torch.exp(5 * x))

dt = config_dict["dt"]
tau = config_dict["tau"]
constrained = config_dict["constrained"]
connectivity_density_rec = config_dict["connectivity_density_rec"]
spectral_rad = config_dict["sr"]
sigma_inp = config_dict["sigma_inp"]
sigma_rec = config_dict["sigma_rec"]
seed = config_dict["seed"]
rng = torch.Generator()
if not seed is None:
    rng.manual_seed(seed)
input_size = config_dict["num_inputs"]
output_size = config_dict["num_outputs"]

# %%
# Task:
n_steps = config_dict["n_steps"]
task_params = config_dict["task_params"]

# %%
# Trainer:
lambda_orth = config_dict["lambda_orth"]
lambda_r = config_dict["lambda_r"]
mask = np.array(config_dict["mask"])
max_iter = config_dict["max_iter"]
tol = config_dict["tol"]
lr = config_dict["lr"]
weight_decay = config_dict["weight_decay"]
same_batch = config_dict["same_batch"]

# %%
# General:
tag = config_dict["tag"]
timestr = time.strftime("%Y%m%d-%H%M%S")
data_folder = os.path.join(config_dict["data_folder"], timestr)

# %%
# # creating instances:
# rnn_torch = RNN_torch(N=N, dt=dt, tau=tau, input_size=input_size, output_size=output_size,
#                       activation=activation, constrained=constrained,
#                       sigma_inp=sigma_inp, sigma_rec=sigma_rec,
#                       connectivity_density_rec=connectivity_density_rec,
#                       spectral_rad=spectral_rad,
#                       random_generator=rng)
task = eval("Task" + taskname)(n_steps=n_steps, n_inputs=input_size, n_outputs=output_size, task_params=task_params)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(rnn_torch.parameters(),
                             lr=lr,
                             weight_decay=weight_decay)
trainer = Trainer(RNN=rnn_torch, Task=task,
                  max_iter=max_iter, tol=tol,
                  optimizer=optimizer, criterion=criterion,
                  lambda_orth=lambda_orth, lambda_r=lambda_r)
datasaver = None

# %%
inputs, targets, conditions = task.get_batch()
ind = 11

fig = plt.figure(figsize = (10, 2))
plt.plot(inputs[0, :, ind], color = 'red', label = 'input 1')
plt.plot(inputs[1, :, ind], color = 'tomato', label = 'input 2')
plt.plot(inputs[2, :, ind], color = 'orange', alpha = 0.5, label = 'input 3')
plt.plot(targets[0, :, ind], color = 'blue', linestyle = '--', label = 'target')
plt.plot(targets[1, :, ind], color = 'skyblue', linestyle = '--', label = 'target')
plt.legend()
plt.show()

# %%
rnn_trained, train_losses, val_losses, net_params = trainer.run_training(train_mask=mask, same_batch=same_batch)
# Out:
# iteration 0, train loss: 2.424956, validation loss: 2.330659
# iteration 1, train loss: 2.332031, validation loss: 2.275554
# iteration 2, train loss: 2.278232, validation loss: 2.246973
# iteration 3, train loss: 2.252651, validation loss: 2.22438
# iteration 4, train loss: 2.222635, validation loss: 2.178482
# iteration 5, train loss: 2.179859, validation loss: 2.092305
# iteration 6, train loss: 2.079229, validation loss: 1.965217
# iteration 7, train loss: 2.007071, validation loss: 1.860022
# iteration 8, train loss: 2.092296, validation loss: 1.830934
# iteration 9, train loss: 1.973165, validation loss: 1.824668
# iteration 10, train loss: 1.911394, validation loss: 1.845203
# iteration 11, train loss: 1.875484, validation loss: 1.806258
# iteration 12, train loss: 1.860398, validation loss: 1.740371
# iteration 13, train loss: 1.79047, validation loss: 1.68461
# iteration 14, train loss: 1.721507, validation loss: 1.64231
# iteration 15, train loss: 1.705352, validation loss: 1.613211
# iteration 16, train loss: 1.660025, validation loss: 1.595206
# iteration 17, train loss: 1.608534, validation loss: 1.532612
# iteration 18, train loss: 1.551032, validation loss: 1.463905
# iteration 19, train loss: 1.48698, validation loss: 1.438664
# iteration 20, train loss: 1.461954, validation loss: 1.401131
# iteration 21, train loss: 1.421326, validation loss: 1.377973
# iteration 22, train loss: 1.390534, validation loss: 1.311995
# iteration 23, train loss: 1.339779, validation loss: 1.271487
# iteration 24, train loss: 1.270932, validation loss: 1.219979
# iteration 25, train loss: 1.22723, validation loss: 1.178437
# iteration 26, train loss: 1.176932, validation loss: 1.136284
# iteration 27, train loss: 1.143682, validation loss: 1.097231
# iteration 28, train loss: 1.096067, validation loss: 1.057554
# iteration 29, train loss: 1.087135, validation loss: 1.017544
# iteration 30, train loss: 1.013206, validation loss: 0.963154
# iteration 31, train loss: 0.985922, validation loss: 0.93446
# iteration 32, train loss: 0.949425, validation loss: 0.907016
# iteration 33, train loss: 0.910669, validation loss: 0.869374
# iteration 34, train loss: 0.872462, validation loss: 0.834424
# iteration 35, train loss: 0.837724, validation loss: 0.798565
# iteration 36, train loss: 0.804706, validation loss: 0.762153
# iteration 37, train loss: 0.78644, validation loss: 0.750588
# iteration 38, train loss: 0.752138, validation loss: 0.725052
# iteration 39, train loss: 0.733877, validation loss: 0.681465
# iteration 40, train loss: 0.703451, validation loss: 0.666746
# iteration 41, train loss: 0.684414, validation loss: 0.642282
# iteration 42, train loss: 0.658114, validation loss: 0.62522
# iteration 43, train loss: 0.65538, validation loss: 0.611313
# iteration 44, train loss: 0.627322, validation loss: 0.592177
# iteration 45, train loss: 0.614212, validation loss: 0.63353
# iteration 46, train loss: 0.616787, validation loss: 0.613719
# iteration 47, train loss: 0.635829, validation loss: 0.618213
# iteration 48, train loss: 0.630491, validation loss: 0.617203
# iteration 49, train loss: 0.628122, validation loss: 0.628425
# iteration 50, train loss: 0.640074, validation loss: 0.633317
# iteration 51, train loss: 0.638525, validation loss: 0.629586
# iteration 52, train loss: 0.627529, validation loss: 0.639861
# iteration 53, train loss: 0.631413, validation loss: 0.607288
# iteration 54, train loss: 0.60377, validation loss: 0.600189
# iteration 55, train loss: 0.615975, validation loss: 0.60188
# iteration 56, train loss: 0.621768, validation loss: 0.575958
# iteration 57, train loss: 0.598276, validation loss: 0.603241
# iteration 58, train loss: 0.59768, validation loss: 0.572806
# iteration 59, train loss: 0.580498, validation loss: 0.57451
# iteration 60, train loss: 0.602157, validation loss: 0.603331
# iteration 61, train loss: 0.589704, validation loss: 0.574864
# iteration 62, train loss: 0.589997, validation loss: 0.587598
# iteration 63, train loss: 0.581358, validation loss: 0.61929
# iteration 64, train loss: 0.587976, validation loss: 0.581885
# iteration 65, train loss: 0.604298, validation loss: 0.555756
# iteration 66, train loss: 0.577364, validation loss: 0.563904
# iteration 67, train loss: 0.57894, validation loss: 0.558278
# iteration 68, train loss: 0.549781, validation loss: 0.555582
# iteration 69, train loss: 0.539507, validation loss: 0.560145
# iteration 70, train loss: 0.541943, validation loss: 0.526863
# iteration 71, train loss: 0.529676, validation loss: 0.531132
# iteration 72, train loss: 0.58408, validation loss: 0.581201
# iteration 73, train loss: 0.575744, validation loss: 0.481523
# iteration 74, train loss: 0.487461, validation loss: 0.451727
# iteration 75, train loss: 0.486082, validation loss: 0.43412
# iteration 76, train loss: 0.454106, validation loss: 0.432402
# iteration 77, train loss: 0.461347, validation loss: 0.359134
# iteration 78, train loss: 0.404281, validation loss: 0.329394
# iteration 79, train loss: 0.369027, validation loss: 0.286976
# iteration 80, train loss: 0.331318, validation loss: 0.322318
# iteration 81, train loss: 0.350205, validation loss: 0.262927
# iteration 82, train loss: 0.305982, validation loss: 0.271268
# iteration 83, train loss: 0.309535, validation loss: 0.271229
# iteration 84, train loss: 0.287035, validation loss: 0.244696
# iteration 85, train loss: 0.288318, validation loss: 0.291223
# iteration 86, train loss: 0.295758, validation loss: 0.25516
# iteration 87, train loss: 0.271168, validation loss: 0.238677
# iteration 88, train loss: 0.251386, validation loss: 0.240691
# iteration 89, train loss: 0.272987, validation loss: 0.192547
# iteration 90, train loss: 0.225605, validation loss: 0.230951
# iteration 91, train loss: 0.276207, validation loss: 0.186855
# iteration 92, train loss: 0.236115, validation loss: 0.218673
# iteration 93, train loss: 0.247809, validation loss: 0.214027
# iteration 94, train loss: 0.256555, validation loss: 0.265006
# iteration 95, train loss: 0.269821, validation loss: 0.29846
# iteration 96, train loss: 0.293617, validation loss: 0.211997
# iteration 97, train loss: 0.246049, validation loss: 0.217373
# iteration 98, train loss: 0.239491, validation loss: 0.229975
# iteration 99, train loss: 0.265674, validation loss: 0.180769
# iteration 100, train loss: 0.221765, validation loss: 0.205662
# iteration 101, train loss: 0.236387, validation loss: 0.245286
# iteration 102, train loss: 0.265725, validation loss: 0.198102
# iteration 103, train loss: 0.215698, validation loss: 0.241925
# iteration 104, train loss: 0.275045, validation loss: 0.189746
# iteration 105, train loss: 0.2135, validation loss: 0.213807
# iteration 106, train loss: 0.225015, validation loss: 0.197949
# iteration 107, train loss: 0.256119, validation loss: 0.169409
# iteration 108, train loss: 0.204511, validation loss: 0.193929
# iteration 109, train loss: 0.242475, validation loss: 0.182112
# iteration 110, train loss: 0.219549, validation loss: 0.180806
# iteration 111, train loss: 0.181978, validation loss: 0.205338
# iteration 112, train loss: 0.23696, validation loss: 0.155834
# iteration 113, train loss: 0.201398, validation loss: 0.193342
# iteration 114, train loss: 0.217761, validation loss: 0.225556
# iteration 115, train loss: 0.231666, validation loss: 0.151494
# iteration 116, train loss: 0.187054, validation loss: 0.225042
# iteration 117, train loss: 0.279149, validation loss: 0.203484
# iteration 118, train loss: 0.224973, validation loss: 0.159279
# iteration 119, train loss: 0.20503, validation loss: 0.208815
# iteration 120, train loss: 0.244185, validation loss: 0.185891
# iteration 121, train loss: 0.190966, validation loss: 0.16718
# iteration 122, train loss: 0.195115, validation loss: 0.181939
# iteration 123, train loss: 0.205074, validation loss: 0.151098
# iteration 124, train loss: 0.212692, validation loss: 0.156749
# iteration 125, train loss: 0.199078, validation loss: 0.191212
# iteration 126, train loss: 0.213664, validation loss: 0.158219
# iteration 127, train loss: 0.180363, validation loss: 0.155145
# iteration 128, train loss: 0.219031, validation loss: 0.159256
# iteration 129, train loss: 0.207946, validation loss: 0.181331
# iteration 130, train loss: 0.222263, validation loss: 0.154576
# iteration 131, train loss: 0.205273, validation loss: 0.148838
# iteration 132, train loss: 0.19169, validation loss: 0.201574
# iteration 133, train loss: 0.195022, validation loss: 0.150601
# iteration 134, train loss: 0.173193, validation loss: 0.146491
# iteration 135, train loss: 0.184771, validation loss: 0.17627
# iteration 136, train loss: 0.168818, validation loss: 0.141414
# iteration 137, train loss: 0.200918, validation loss: 0.17714
# iteration 138, train loss: 0.173535, validation loss: 0.151913
# iteration 139, train loss: 0.176789, validation loss: 0.139959
# iteration 140, train loss: 0.196611, validation loss: 0.170963
# iteration 141, train loss: 0.180418, validation loss: 0.154343
# iteration 142, train loss: 0.157091, validation loss: 0.128169
# iteration 143, train loss: 0.174407, validation loss: 0.148682
# iteration 144, train loss: 0.150125, validation loss: 0.147126
# iteration 145, train loss: 0.172469, validation loss: 0.149699
# iteration 146, train loss: 0.147437, validation loss: 0.139768
# iteration 147, train loss: 0.182584, validation loss: 0.136918
# iteration 148, train loss: 0.178067, validation loss: 0.148508
# iteration 149, train loss: 0.158168, validation loss: 0.136002
# iteration 150, train loss: 0.159942, validation loss: 0.135234
# iteration 151, train loss: 0.154504, validation loss: 0.137276
# iteration 152, train loss: 0.167048, validation loss: 0.149914
# iteration 153, train loss: 0.159673, validation loss: 0.128586
# iteration 154, train loss: 0.162447, validation loss: 0.127532
# iteration 155, train loss: 0.167624, validation loss: 0.134709
# iteration 156, train loss: 0.173333, validation loss: 0.117674
# iteration 157, train loss: 0.180734, validation loss: 0.134454
# iteration 158, train loss: 0.144844, validation loss: 0.120408
# iteration 159, train loss: 0.171195, validation loss: 0.148632
# iteration 160, train loss: 0.179259, validation loss: 0.132074
# iteration 161, train loss: 0.151497, validation loss: 0.134227
# iteration 162, train loss: 0.154797, validation loss: 0.150104
# iteration 163, train loss: 0.163215, validation loss: 0.136197
# iteration 164, train loss: 0.154537, validation loss: 0.159072
# iteration 165, train loss: 0.138229, validation loss: 0.132988
# iteration 166, train loss: 0.157684, validation loss: 0.148669
# iteration 167, train loss: 0.164031, validation loss: 0.11804
# iteration 168, train loss: 0.154673, validation loss: 0.126741
# iteration 169, train loss: 0.174867, validation loss: 0.159336
# iteration 170, train loss: 0.16561, validation loss: 0.136696
# iteration 171, train loss: 0.150582, validation loss: 0.12923
# iteration 172, train loss: 0.190287, validation loss: 0.147408
# iteration 173, train loss: 0.156006, validation loss: 0.147328
# iteration 174, train loss: 0.184, validation loss: 0.136941
# iteration 175, train loss: 0.183874, validation loss: 0.151994
# iteration 176, train loss: 0.159694, validation loss: 0.132938
# iteration 177, train loss: 0.145201, validation loss: 0.130102
# iteration 178, train loss: 0.140712, validation loss: 0.120223
# iteration 179, train loss: 0.15994, validation loss: 0.131359
# iteration 180, train loss: 0.158506, validation loss: 0.137386
# iteration 181, train loss: 0.161874, validation loss: 0.118484
# iteration 182, train loss: 0.147762, validation loss: 0.127028
# iteration 183, train loss: 0.167846, validation loss: 0.156597
# iteration 184, train loss: 0.170843, validation loss: 0.125503
# iteration 185, train loss: 0.143155, validation loss: 0.121812
# iteration 186, train loss: 0.171878, validation loss: 0.144346
# iteration 187, train loss: 0.146576, validation loss: 0.13985
# iteration 188, train loss: 0.154738, validation loss: 0.139547
# iteration 189, train loss: 0.154735, validation loss: 0.132613
# iteration 190, train loss: 0.134087, validation loss: 0.151475
# iteration 191, train loss: 0.158807, validation loss: 0.151553
# iteration 192, train loss: 0.174085, validation loss: 0.137247
# iteration 193, train loss: 0.138889, validation loss: 0.136802
# iteration 194, train loss: 0.157817, validation loss: 0.145935
# iteration 195, train loss: 0.161097, validation loss: 0.133575
# iteration 196, train loss: 0.143008, validation loss: 0.135519
# iteration 197, train loss: 0.15709, validation loss: 0.109956
# iteration 198, train loss: 0.150591, validation loss: 0.115696
# iteration 199, train loss: 0.148015, validation loss: 0.125866
# iteration 200, train loss: 0.169494, validation loss: 0.138937
# iteration 201, train loss: 0.132082, validation loss: 0.120291
# iteration 202, train loss: 0.146919, validation loss: 0.131937
# iteration 203, train loss: 0.150865, validation loss: 0.141844
# iteration 204, train loss: 0.147464, validation loss: 0.167237
# iteration 205, train loss: 0.160706, validation loss: 0.129574
# iteration 206, train loss: 0.140033, validation loss: 0.148301
# iteration 207, train loss: 0.130148, validation loss: 0.136158
# iteration 208, train loss: 0.161403, validation loss: 0.127265
# iteration 209, train loss: 0.187078, validation loss: 0.148528
# iteration 210, train loss: 0.174988, validation loss: 0.133816
# iteration 211, train loss: 0.154522, validation loss: 0.137472
# iteration 212, train loss: 0.139609, validation loss: 0.116231
# iteration 213, train loss: 0.159794, validation loss: 0.117764
# iteration 214, train loss: 0.120612, validation loss: 0.118664
# iteration 215, train loss: 0.147586, validation loss: 0.137306
# iteration 216, train loss: 0.135235, validation loss: 0.124841
# iteration 217, train loss: 0.158521, validation loss: 0.129464
# iteration 218, train loss: 0.17557, validation loss: 0.148011
# iteration 219, train loss: 0.178062, validation loss: 0.136539
# iteration 220, train loss: 0.165866, validation loss: 0.137287
# iteration 221, train loss: 0.129512, validation loss: 0.120768
# iteration 222, train loss: 0.155977, validation loss: 0.136081
# iteration 223, train loss: 0.144594, validation loss: 0.121161
# iteration 224, train loss: 0.137575, validation loss: 0.129404
# iteration 225, train loss: 0.163025, validation loss: 0.130819
# iteration 226, train loss: 0.15646, validation loss: 0.149498
# iteration 227, train loss: 0.143372, validation loss: 0.135053
# iteration 228, train loss: 0.122031, validation loss: 0.134305
# iteration 229, train loss: 0.153684, validation loss: 0.131301
# iteration 230, train loss: 0.153901, validation loss: 0.130994
# iteration 231, train loss: 0.148916, validation loss: 0.122802
# iteration 232, train loss: 0.156451, validation loss: 0.116729
# iteration 233, train loss: 0.139009, validation loss: 0.143277
# iteration 234, train loss: 0.162108, validation loss: 0.128467
# iteration 235, train loss: 0.134994, validation loss: 0.12708
# iteration 236, train loss: 0.163152, validation loss: 0.127665
# iteration 237, train loss: 0.165478, validation loss: 0.120372
# iteration 238, train loss: 0.182808, validation loss: 0.157644
# iteration 239, train loss: 0.128365, validation loss: 0.14814
# iteration 240, train loss: 0.135955, validation loss: 0.144906
# iteration 241, train loss: 0.12573, validation loss: 0.157083
# iteration 242, train loss: 0.168318, validation loss: 0.143026
# iteration 243, train loss: 0.14518, validation loss: 0.147052
# iteration 244, train loss: 0.136962, validation loss: 0.126679
# iteration 245, train loss: 0.123645, validation loss: 0.129909
# iteration 246, train loss: 0.144914, validation loss: 0.147545
# iteration 247, train loss: 0.147241, validation loss: 0.135954
# iteration 248, train loss: 0.149125, validation loss: 0.139013
# iteration 249, train loss: 0.140664, validation loss: 0.129006
# iteration 250, train loss: 0.165993, validation loss: 0.141093
# iteration 251, train loss: 0.163875, validation loss: 0.113862
# iteration 252, train loss: 0.137454, validation loss: 0.126678
# iteration 253, train loss: 0.1414, validation loss: 0.126383
# iteration 254, train loss: 0.133523, validation loss: 0.148032
# iteration 255, train loss: 0.137963, validation loss: 0.142668
# iteration 256, train loss: 0.151304, validation loss: 0.133873
# iteration 257, train loss: 0.15325, validation loss: 0.157202
# iteration 258, train loss: 0.148017, validation loss: 0.127258
# iteration 259, train loss: 0.153576, validation loss: 0.11832
# iteration 260, train loss: 0.136801, validation loss: 0.157128
# iteration 261, train loss: 0.154412, validation loss: 0.122005
# iteration 262, train loss: 0.149812, validation loss: 0.146873
# iteration 263, train loss: 0.182555, validation loss: 0.135072
# iteration 264, train loss: 0.129204, validation loss: 0.142641
# iteration 265, train loss: 0.156979, validation loss: 0.134193
# iteration 266, train loss: 0.161219, validation loss: 0.123282
# iteration 267, train loss: 0.156881, validation loss: 0.157071
# iteration 268, train loss: 0.154257, validation loss: 0.139081
# iteration 269, train loss: 0.164883, validation loss: 0.13809
# iteration 270, train loss: 0.146123, validation loss: 0.14852
# iteration 271, train loss: 0.142051, validation loss: 0.149243
# iteration 272, train loss: 0.156362, validation loss: 0.137622
# iteration 273, train loss: 0.156618, validation loss: 0.139651
# iteration 274, train loss: 0.157425, validation loss: 0.138284
# iteration 275, train loss: 0.122105, validation loss: 0.135473
# iteration 276, train loss: 0.15331, validation loss: 0.135716
# iteration 277, train loss: 0.14043, validation loss: 0.136808
# iteration 278, train loss: 0.145335, validation loss: 0.144156
# iteration 279, train loss: 0.170902, validation loss: 0.156668
# iteration 280, train loss: 0.17506, validation loss: 0.128632
# iteration 281, train loss: 0.165902, validation loss: 0.156127
# iteration 282, train loss: 0.164183, validation loss: 0.130761
# iteration 283, train loss: 0.14882, validation loss: 0.143485
# iteration 284, train loss: 0.130747, validation loss: 0.144543
# iteration 285, train loss: 0.150647, validation loss: 0.151056
# iteration 286, train loss: 0.141788, validation loss: 0.129223
# iteration 287, train loss: 0.157438, validation loss: 0.129827
# iteration 288, train loss: 0.131311, validation loss: 0.142481
# iteration 289, train loss: 0.14227, validation loss: 0.14623
# iteration 290, train loss: 0.145791, validation loss: 0.120121
# iteration 291, train loss: 0.160036, validation loss: 0.132595
# iteration 292, train loss: 0.139611, validation loss: 0.151378
# iteration 293, train loss: 0.138715, validation loss: 0.107344
# iteration 294, train loss: 0.171959, validation loss: 0.118957
# iteration 295, train loss: 0.14115, validation loss: 0.12937
# iteration 296, train loss: 0.137902, validation loss: 0.122364
# iteration 297, train loss: 0.149635, validation loss: 0.144573
# iteration 298, train loss: 0.15428, validation loss: 0.134018
# iteration 299, train loss: 0.157919, validation loss: 0.142155
# iteration 300, train loss: 0.138675, validation loss: 0.136534
# iteration 301, train loss: 0.150279, validation loss: 0.135773
# iteration 302, train loss: 0.143324, validation loss: 0.123404
# iteration 303, train loss: 0.10911, validation loss: 0.123551
# iteration 304, train loss: 0.149127, validation loss: 0.133453
# iteration 305, train loss: 0.129305, validation loss: 0.133946
# iteration 306, train loss: 0.152309, validation loss: 0.125896
# iteration 307, train loss: 0.114817, validation loss: 0.157825
# iteration 308, train loss: 0.136639, validation loss: 0.124667
# iteration 309, train loss: 0.150281, validation loss: 0.141834
# iteration 310, train loss: 0.145967, validation loss: 0.137215
# iteration 311, train loss: 0.143649, validation loss: 0.126564
# iteration 312, train loss: 0.147867, validation loss: 0.110043
# iteration 313, train loss: 0.168036, validation loss: 0.155674
# iteration 314, train loss: 0.14366, validation loss: 0.142909
# iteration 315, train loss: 0.139955, validation loss: 0.122187
# iteration 316, train loss: 0.133899, validation loss: 0.124885
# iteration 317, train loss: 0.161546, validation loss: 0.135414
# iteration 318, train loss: 0.140467, validation loss: 0.131587
# iteration 319, train loss: 0.149409, validation loss: 0.116851
# iteration 320, train loss: 0.136702, validation loss: 0.124015
# iteration 321, train loss: 0.121539, validation loss: 0.143141
# iteration 322, train loss: 0.141389, validation loss: 0.125601
# iteration 323, train loss: 0.144224, validation loss: 0.128578
# iteration 324, train loss: 0.146276, validation loss: 0.129307
# iteration 325, train loss: 0.169481, validation loss: 0.12364
# iteration 326, train loss: 0.133295, validation loss: 0.127485
# iteration 327, train loss: 0.132803, validation loss: 0.142722
# iteration 328, train loss: 0.147282, validation loss: 0.146635
# iteration 329, train loss: 0.156434, validation loss: 0.115445
# iteration 330, train loss: 0.151625, validation loss: 0.149941
# iteration 331, train loss: 0.126641, validation loss: 0.12507
# iteration 332, train loss: 0.144031, validation loss: 0.133413
# iteration 333, train loss: 0.170709, validation loss: 0.117159
# iteration 334, train loss: 0.126843, validation loss: 0.135495
# iteration 335, train loss: 0.163611, validation loss: 0.15214
# iteration 336, train loss: 0.197415, validation loss: 0.161492
# iteration 337, train loss: 0.135258, validation loss: 0.128759
# iteration 338, train loss: 0.145881, validation loss: 0.133256
# iteration 339, train loss: 0.136154, validation loss: 0.142148
# iteration 340, train loss: 0.156646, validation loss: 0.169727
# iteration 341, train loss: 0.150257, validation loss: 0.141099
# iteration 342, train loss: 0.140194, validation loss: 0.141159
# iteration 343, train loss: 0.127263, validation loss: 0.133188
# iteration 344, train loss: 0.147968, validation loss: 0.144988
# iteration 345, train loss: 0.119769, validation loss: 0.142425
# iteration 346, train loss: 0.149134, validation loss: 0.12939
# iteration 347, train loss: 0.137873, validation loss: 0.137807
# iteration 348, train loss: 0.136293, validation loss: 0.131275
# iteration 349, train loss: 0.158074, validation loss: 0.141149
# iteration 350, train loss: 0.11711, validation loss: 0.121902
# iteration 351, train loss: 0.128669, validation loss: 0.152082
# iteration 352, train loss: 0.126457, validation loss: 0.112319
# iteration 353, train loss: 0.158594, validation loss: 0.143192
# iteration 354, train loss: 0.141747, validation loss: 0.183829
# iteration 355, train loss: 0.134825, validation loss: 0.135778
# iteration 356, train loss: 0.144806, validation loss: 0.158327
# iteration 357, train loss: 0.121119, validation loss: 0.142386
# iteration 358, train loss: 0.120149, validation loss: 0.119493
# iteration 359, train loss: 0.127489, validation loss: 0.149906
# iteration 360, train loss: 0.132017, validation loss: 0.143002
# iteration 361, train loss: 0.146185, validation loss: 0.132402
# iteration 362, train loss: 0.160878, validation loss: 0.111461
# iteration 363, train loss: 0.136278, validation loss: 0.11857
# iteration 364, train loss: 0.15342, validation loss: 0.113786
# iteration 365, train loss: 0.144224, validation loss: 0.124601
# iteration 366, train loss: 0.138407, validation loss: 0.130911
# iteration 367, train loss: 0.141864, validation loss: 0.120062
# iteration 368, train loss: 0.131528, validation loss: 0.114303
# iteration 369, train loss: 0.141272, validation loss: 0.113285
# iteration 370, train loss: 0.163931, validation loss: 0.152981
# iteration 371, train loss: 0.122676, validation loss: 0.169309
# iteration 372, train loss: 0.143363, validation loss: 0.163073
# iteration 373, train loss: 0.142268, validation loss: 0.141164
# iteration 374, train loss: 0.143521, validation loss: 0.133072
# iteration 375, train loss: 0.152389, validation loss: 0.139275
# iteration 376, train loss: 0.143175, validation loss: 0.127119
# iteration 377, train loss: 0.138057, validation loss: 0.148189
# iteration 378, train loss: 0.154734, validation loss: 0.148922
# iteration 379, train loss: 0.144398, validation loss: 0.139003
# iteration 380, train loss: 0.138221, validation loss: 0.133163
# iteration 381, train loss: 0.154711, validation loss: 0.161809
# iteration 382, train loss: 0.133691, validation loss: 0.15478
# iteration 383, train loss: 0.180097, validation loss: 0.137325
# iteration 384, train loss: 0.153335, validation loss: 0.122857
# iteration 385, train loss: 0.150751, validation loss: 0.139659
# iteration 386, train loss: 0.164851, validation loss: 0.140868
# iteration 387, train loss: 0.162713, validation loss: 0.147421
# iteration 388, train loss: 0.161171, validation loss: 0.119988
# iteration 389, train loss: 0.1417, validation loss: 0.137524
# iteration 390, train loss: 0.131257, validation loss: 0.153482
# iteration 391, train loss: 0.170122, validation loss: 0.133176
# iteration 392, train loss: 0.140022, validation loss: 0.126434
# iteration 393, train loss: 0.142291, validation loss: 0.120579
# iteration 394, train loss: 0.139444, validation loss: 0.125855
# iteration 395, train loss: 0.135379, validation loss: 0.117561
# iteration 396, train loss: 0.177249, validation loss: 0.120117
# iteration 397, train loss: 0.134655, validation loss: 0.101094
# iteration 398, train loss: 0.140752, validation loss: 0.151143
# iteration 399, train loss: 0.139511, validation loss: 0.129124

# %%
fig_trainloss = plt.figure(figsize=(10, 3))
plt.plot(train_losses, color='r', label='train loss (log scale)')
plt.plot(val_losses, color='b', label='valid loss (log scale)')
plt.yscale("log")
plt.grid(True)
plt.legend(fontsize=16)
if disp:
    plt.show()
if not (datasaver is None): datasaver.save_figure(fig_trainloss, "train&valid_loss")

# %%
# validate
RNN_valid = RNN_numpy(N=net_params["N"],
                      dt=net_params["dt"],
                      tau=net_params["tau"],
                      activation=numpify(activation),
                      W_inp=net_params["W_inp"],
                      W_rec=net_params["W_rec"],
                      W_out=net_params["W_out"],
                      bias_rec=net_params["bias_rec"],
                      y_init=net_params["y_init"])

# %%
analyzer = PerformanceAnalyzer(RNN_valid)
score_function = lambda x, y: np.mean((x - y) ** 2)
input_batch_valid, target_batch_valid, conditions_valid = task.get_batch()
score = analyzer.get_validation_score(score_function, input_batch_valid, target_batch_valid,
                                      mask, sigma_rec=sigma_rec, sigma_inp=sigma_inp)

# %%
print(f"MSE validation: {np.round(score, 5)}")
if not (datasaver is None): datasaver.save_data(config_dict, "config.json")
if not (datasaver is None): datasaver.save_data(best_net_params, f"params_{taskname}_{np.round(score, 5)}.pkl")
# Out:
# MSE validation: 0.14067

# %%
print(f"Plotting random trials")
inds = np.random.choice(np.arange(input_batch_valid.shape[-1]), 12)
inputs = input_batch_valid[..., inds]
targets = target_batch_valid[..., inds]

fig_trials = analyzer.plot_trials(inputs, targets, mask, sigma_rec=sigma_rec, sigma_inp=sigma_inp)
if disp:
    plt.show()
if not (datasaver is None): datasaver.save_figure(fig_trials, "random_trials")
# Out:
# Plotting random trials

# %%
dsa = DynamicSystemAnalyzer(RNN_valid)
params = {"fun_tol" : 0.05,
          "diff_cutoff":1e-4,
          "sigma_init_guess":15,
          "patience":100,
          "stop_length":100,
          "mode":"approx"}
dsa.get_fixed_points(Input=np.array([0, 0, 0]), **params)
dsa.get_fixed_points(Input=np.array([0, 0, 1]), **params)

# %%
all_points = np.vstack([dsa.fp_data[str([0, 0, 0])][type] for type in list(dsa.fp_data[str([0, 0, 0])].keys())])
pca = PCA(n_components=2)
pca.fit(all_points)
P = np.zeros((RNN_valid.N, 3))
P[:, 0] = RNN_valid.W_out[0, :]
P[:, 1:] = pca.components_.T
P = orthonormalize(P)

# %%
# %matplotlib widget

fig_fp = dsa.plot_fixed_points(projection='3D', P=P)
plt.xlabel("Output axis", fontsize=16)
# plt.ylabel("Line", fontsize=16)
if disp:
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
